# %% [markdown]
# # Seasonal Agriculture Performance Analysis
# **Student Name:** Praful Patil
# **College:** SSBT's College of Engineering and Technology, Jalgaon
# **AICTE STU ID:** STU66bf8a12bc2071723812370
# **Project Track:** VOIS AICTE Batch 1 - Data Visualization Major Project

# %% [markdown]
# ## 1. Import Libraries and Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual style
sns.set_theme(style='whitegrid')
plt.rcParams['font.size'] = 11

# Load dataset
df = pd.read_csv('seasonal_agriculture_performance_dataset.csv')
df.head()

# %% [markdown]
# ## 2. Data Cleaning & Inspection

# %%
# Inspect info and missing values
print('Missing Values:
', df.isnull().sum()[df.isnull().sum() > 0])

# Impute numerical missing fields with median
df['Rainfall_mm'].fillna(df['Rainfall_mm'].median(), inplace=True)
df['Soil_Moisture_pct'].fillna(df['Soil_Moisture_pct'].median(), inplace=True)
df['Yield_Tonnes_Ha'].fillna(df['Yield_Tonnes_Ha'].median(), inplace=True)

# %% [markdown]
# ## 3. Exploratory Data Analysis: Seasonal Yield & Profitability

# %%
season_summary = df.groupby('Season')[['Yield_Tonnes_Ha', 'Profit_INR', 'Rainfall_mm', 'Disease_Pest_Risk_pct']].mean()
display(season_summary)

# Bar chart for seasonal profits
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='Season', y='Profit_INR', palette='Greens_d', ci=None)
plt.title('Average Farm Profitability by Season (INR)')
plt.ylabel('Profit (INR)')
plt.show()

# %% [markdown]
# ## 4. Resource Efficiency Analysis: Irrigation Methods

# %%
irr_summary = df.groupby('Irrigation_Method')[['Water_Efficiency_t_per_1000m3', 'Profit_INR', 'Yield_Tonnes_Ha']].mean()
display(irr_summary)

plt.figure(figsize=(9, 5))
sns.barplot(data=df, x='Irrigation_Method', y='Water_Efficiency_t_per_1000m3', palette='Blues_d', ci=None)
plt.title('Water Use Efficiency across Irrigation Methods (t / 1000m³)')
plt.ylabel('Tonnes per 1000m³')
plt.show()

# %% [markdown]
# ## 5. Summary Findings & Conclusions
# 1. **Kharif Season** yields the highest financial return (₹178,914 avg profit) due to abundant monsoon rainfall.
# 2. **Drip Irrigation** demonstrates superior ROI (₹219,626 avg profit) and efficient water usage (6.27 t/1000m³).
# 3. **Pest Risk** peaks during humid Kharif months (54.5%), requiring proactive pest management.
